# %%
import numpy
import pandas
import matplotlib.pyplot as pl

# %%
s1=pandas.Series(numpy.array(['credit','netbanking','debit','upi','cod']))
s2=pandas.Series(numpy.array([19723,2156,14380,31659,6433]))

# %%
print(s1)
# Out:
# 0        credit
# 1    netbanking
# 2         debit
# 3           upi
# 4           cod
# dtype: object

# %%
print(s2)
# Out:
# 0    19723
# 1     2156
# 2    14380
# 3    31659
# 4     6433
# dtype: int64

# %%
pl.pie(s2,labels=s1,autopct='%.1f%%')
pl.show()
