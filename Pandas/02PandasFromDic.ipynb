# %% [markdown]
# **Using dictionary as a data source for Pandas**

# %%
import pandas

# %%
emp={
    'empnm':['jos buttler','joe root','pat cummins','charles leclerc'],
    'department':['admin','sales','admin','marketing'],
    'post':['manager','executive','manager','executive'],
    'location':['manchester','london','sydney','monaco'],
    'salary':[73500,49800,67300,85200]
}

# %%
df=pandas.DataFrame(emp)
print(df)
# Out:
#              empnm department       post    location  salary
# 0      jos buttler      admin    manager  manchester   73500
# 1         joe root      sales  executive      london   49800
# 2      pat cummins      admin    manager      sydney   67300
# 3  charles leclerc  marketing  executive      monaco   85200
