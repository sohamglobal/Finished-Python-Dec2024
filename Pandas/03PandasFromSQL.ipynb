# %% [markdown]
# **Retrieve data from SQL DB and store in DataFrame**

# %%
pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 3.5 MB/s eta 0:00:00
# ...

# %%
import pymysql
import pandas

# %%
con=pymysql.connect(host='mysql-java-javaee-project.c.aivencloud.com',port=19179,user='avnadmin',password='AVNS_TEZ17S2CIEzgqRcBnb0',database='sharayudb')

# %%
df=pandas.read_sql("select * from employees",con)
print(df)
# Out:
# <ipython-input-7-6c92d71df3fc>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pandas.read_sql("select * from employees",con)
#     empno           empnm         dept                 post   location  \
# 0     100     Musaib umer  development        Java devloper     london
# 1     102         Akshata  development             Employee     mumbai
# 2     122           sejal           IT            Developer     mumbai
# 3     123        praffull    marketing            executive     mumbai
# 4     124         sharayu  development         data analyst     london
# 5     125        shailaja      finance              manager    karachi
# 6     126           megha  development       java developer    kolkata
# 7     127           soham         data  cloud data engineer  liverpool
# ...

# %%
df1=pandas.read_sql("select * from accounts",con)
print(df1)
# Out:
# <ipython-input-9-a92495020d49>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df1=pandas.read_sql("select * from accounts",con)
#     accno                    accnm  acctype   balance
# 0     992                  sharayu    fixed  226059.0
# 1     993                 praffull  current   84054.0
# 2    1001          charles leclerc   saving   48672.0
# 3    1002          maria sharapova    fixed   25468.0
# 4    1003         mitchell johnson  current   26166.0
# 5    1004              edan hazard   saving   44670.0
# 6    1005       robert lewandowski   saving   23363.0
# 7    1006            gabriel jesus    fixed   40903.0
# 8    1008            marcos alonso   saving   36666.0
# 9    1009               david luiz  current   29547.0
# 10   1010              steve smith    fixed   67418.0
# ...

# %%
df2=pandas.read_sql("select * from accounts where balance between 35000 and 50000",con)
print(df2)
# Out:
# <ipython-input-11-68a183979028>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df2=pandas.read_sql("select * from accounts where balance between 35000 and 50000",con)
#     accno                accnm  acctype  balance
# 0    1001      charles leclerc   saving  48672.0
# 1    1004          edan hazard   saving  44670.0
# 2    1006        gabriel jesus    fixed  40903.0
# 3    1008        marcos alonso   saving  36666.0
# 4    1013     antoine griezman    fixed  41498.0
# 5    1033  alexandre lacazette   saving  39183.0
# 6    1040          adil rashid      ppf  45647.0
# 7    1044           alex hales   saving  41685.0
# 8    1052       max verstappen   saving  38747.0
# 9    1054          harry brook   saving  38500.0
# 10   1055        glenn mcgrath  current  41300.0
# 11   1056       adam gilchrist      ppf  35000.0

# %%
df4=pandas.read_sql("select customers.custnm,cars.company,cars.modelnm from customers inner join cars on customers.carid=cars.carid",con)
print(df4)
# Out:
# <ipython-input-15-54dbe2fa382a>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df4=pandas.read_sql("select customers.custnm,cars.company,cars.modelnm from customers inner join cars on customers.carid=cars.carid",con)
#                    custnm        company   modelnm
# 0                Joe Root          Skoda    Kushaq
# 1            Boris Becker          Honda     Amaze
# 2      Michael Schumacher            BMW        XM
# 3   Arnold Schwarzenegger         Toyota  Fortuner
# 4             Jos Buttler     Volkswagen    Tiguan
# 5             Steffi Graf     Volkswagen    Virtus
# 6            Keanu Reeves         Toyota  Fortuner
# 7        Sabastian Vettel          Skoda    Kodiaq
# 8              Tom Cruise            BMW        XM
# 9           Roger Federer          Honda      City
# ...

# %%
df4=pandas.read_sql("select customers.custnm,cars.company,cars.modelnm from customers left outer join cars on customers.carid=cars.carid",con)
print(df4)
# Out:
# <ipython-input-17-91389e5b514e>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df4=pandas.read_sql("select customers.custnm,cars.company,cars.modelnm from customers left outer join cars on customers.carid=cars.carid",con)
#                    custnm        company   modelnm
# 0                Joe Root          Skoda    Kushaq
# 1            Boris Becker          Honda     Amaze
# 2      Michael Schumacher            BMW        XM
# 3   Arnold Schwarzenegger         Toyota  Fortuner
# 4             Jos Buttler     Volkswagen    Tiguan
# 5        Rebecca Ferguson           None      None
# 6             Steffi Graf     Volkswagen    Virtus
# 7            Keanu Reeves         Toyota  Fortuner
# 8        Sabastian Vettel          Skoda    Kodiaq
# 9              Tom Cruise            BMW        XM
# ...
