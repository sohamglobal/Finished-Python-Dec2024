# %%
import pandas

# %%
dic={
    'mumbai':[32,35,29],
    'london':[7,11,6],
    'sydney':[12,9,17],
    'dubai':[36,32,31]
}

# %%
df=pandas.DataFrame(dic)
print(df)
# Out:
#    mumbai  london  sydney  dubai
# 0      32       7      12     36
# 1      35      11       9     32
# 2      29       6      17     31

# %%
df=df.add(1)
print(df)
# Out:
#    mumbai  london  sydney  dubai
# 0      33       8      13     37
# 1      36      12      10     33
# 2      30       7      18     32

# %%
df=df.sub(1.5)
print(df)
# Out:
#    mumbai  london  sydney  dubai
# 0    31.5     6.5    11.5   35.5
# 1    34.5    10.5     8.5   31.5
# 2    28.5     5.5    16.5   30.5

# %%
df=df.mul(2)
print(df)
# Out:
#    mumbai  london  sydney  dubai
# 0    63.0    13.0    23.0   71.0
# 1    69.0    21.0    17.0   63.0
# 2    57.0    11.0    33.0   61.0

# %%
df=df.div(3)
print(df)
# Out:
#    mumbai    london     sydney      dubai
# 0    21.0  4.333333   7.666667  23.666667
# 1    23.0  7.000000   5.666667  21.000000
# 2    19.0  3.666667  11.000000  20.333333
