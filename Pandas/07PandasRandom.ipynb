# %% [markdown]
# **Pandas DF of random data**

# %%
import numpy
import pandas

# %%
df=pandas.DataFrame(numpy.random.rand(10,3),columns=['US Dollar','Euro','Dinar'])

# %%
print(df)
# Out:
#    US Dollar      Euro     Dinar
# 0   0.380365  0.382924  0.763661
# 1   0.909013  0.842821  0.226366
# 2   0.342004  0.954325  0.871610
# 3   0.493833  0.653022  0.602105
# 4   0.939765  0.537723  0.862357
# 5   0.211066  0.106757  0.144449
# 6   0.657337  0.759590  0.416222
# 7   0.423374  0.340412  0.054095
# 8   0.407990  0.071687  0.964268
# 9   0.862167  0.750663  0.403181
