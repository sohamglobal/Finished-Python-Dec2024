# %% [markdown]
# **Import data from Excel sheet to Pandas DF**

# %%
import pandas

# %%
file=pandas.ExcelFile("countrydetails.xlsx")

# %%
df=file.parse("Sheet1")

# %%
print(df)
# Out:
#          Country           Capital        Currency  \
# 0    Afghanistan             Kabul         Afghani
# 1        Albania            Tirane             Lek
# 2        Algeria           Algiers  Algerian Dinar
# 3        Andorra  Andorra la Vella            Euro
# 4         Angola            Luanda          Kwanza
# ..           ...               ...             ...
# 141        Qatar              Doha    Qatari Riyal
# 142      Romania         Bucharest  Romanian Rupee
# 143      Romania         Bucharest  Romanian Rupee
# 144       Russia            Moscow           Ruble
# 145       Rwanda            Kigali   Rwandan Franc
#
#               Primary Language(s)
# 0            Dari Persian; Pashto
# 1                        Albanian
# 2       Arabic; Tamazight; French
# 3                         Catalan
# 4                      Portuguese
# ..                            ...
# 141                        Arabic
# 142                      Romanian
# ...

# %%
file=pandas.ExcelFile("population.xlsx")
df=file.parse("Sheet2")
print(df)
# Out:
#                                 Country    Region           Subregion  \
# 0                              China[a]      Asia        Eastern Asia
# 1                                 India      Asia       Southern Asia
# 2                         United States  Americas    Northern America
# 3                             Indonesia      Asia  South-eastern Asia
# 4                              Pakistan      Asia       Southern Asia
# ..                                  ...       ...                 ...
# 228         Montserrat (United Kingdom)  Americas           Caribbean
# 229   Falkland Islands (United Kingdom)  Americas       South America
# 230                                Niue   Oceania           Polynesia
# 231               Tokelau (New Zealand)   Oceania           Polynesia
# 232                     Vatican City[z]    Europe     Southern Europe
#
#      Population2018  Population2019  Change
# 0        1427647786      1433783686  0.0043
# ...

# %% [markdown]
# **Export DF data to a CSV dataset**

# %%
df.to_csv("populationdata.csv")
