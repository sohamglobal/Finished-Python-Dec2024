# %%
import pandas

# %%
url="https://raw.githubusercontent.com/sohamglobal/datasets/refs/heads/main/prod.csv"

# %%
df=pandas.read_csv(url)
print(df)
# Out:
#    prodid              prodnm     company      price
# 0   BMW15             BMW car         BMW  8900000.0
# 1   gt261         6 Series GT         BMW   151515.0
# 2   hp419  development laptop          HP    54600.0
# 3   if423     washing machine         ifb    22890.0
# 4   ip627            iphone 8       apple    58500.0
# 5   lt532        Smart FHD TV     samsung    24500.0
# 6   ms488         Surface Pro   microsoft   129399.0
# 7   ph618     washing machine     philips    23200.0
# 8   sm531          galaxy f13     samsung    12750.0
# 9   sp841              Superb       Skoda  2854600.0
# 10  tg765              Tiguan  Volkswagen  2914900.0
# 11  ui548      User Interface     unknown   687654.0
# 12  vn488               Vento  Volkswagen    14500.0
# 13  x1562              X1 Suv         BMW  3469100.0

# %%
print(df.head(3))
# Out:
#   prodid              prodnm company      price
# 0  BMW15             BMW car     BMW  8900000.0
# 1  gt261         6 Series GT     BMW   151515.0
# 2  hp419  development laptop      HP    54600.0

# %%
print(df.tail(2))
# Out:
#    prodid  prodnm     company      price
# 12  vn488   Vento  Volkswagen    14500.0
# 13  x1562  X1 Suv         BMW  3469100.0

# %%
res=pandas.concat([df.head(3),df.tail(2)])
print(res)
# Out:
#    prodid              prodnm     company      price
# 0   BMW15             BMW car         BMW  8900000.0
# 1   gt261         6 Series GT         BMW   151515.0
# 2   hp419  development laptop          HP    54600.0
# 12  vn488               Vento  Volkswagen    14500.0
# 13  x1562              X1 Suv         BMW  3469100.0

# %%
df1=df[['prodnm']]
df2=df[['company','price']]

# %%
res=pandas.concat([df1,df2],axis=1)
print(res)
# Out:
#                 prodnm     company      price
# 0              BMW car         BMW  8900000.0
# 1          6 Series GT         BMW   151515.0
# 2   development laptop          HP    54600.0
# 3      washing machine         ifb    22890.0
# 4             iphone 8       apple    58500.0
# 5         Smart FHD TV     samsung    24500.0
# 6          Surface Pro   microsoft   129399.0
# 7      washing machine     philips    23200.0
# 8           galaxy f13     samsung    12750.0
# 9               Superb       Skoda  2854600.0
# 10              Tiguan  Volkswagen  2914900.0
# 11      User Interface     unknown   687654.0
# 12               Vento  Volkswagen    14500.0
# 13              X1 Suv         BMW  3469100.0
