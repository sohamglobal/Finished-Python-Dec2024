# %%
import numpy

# %%
arr1=numpy.array([[12,23],[45,56],[78,89]])
print(arr1)
arr1+=5
print(arr1)
# Out:
# [[12 23]
#  [45 56]
#  [78 89]]
# [[17 28]
#  [50 61]
#  [83 94]]

# %%
arr2=numpy.array([[2,3],[4,5],[2,4]])
print(arr2)
# Out:
# [[2 3]
#  [4 5]
#  [2 4]]

# %%
print(arr1+arr2)
# Out:
# [[19 31]
#  [54 66]
#  [85 98]]

# %%
print(arr1*arr2)
# Out:
# [[ 34  84]
#  [200 305]
#  [166 376]]

# %%
arr=numpy.array([1,2,3,4,5])

# %%
print(numpy.sum(arr))
# Out:
# 15

# %%
print(numpy.prod(arr))
# Out:
# 120

# %%
print(numpy.add(arr1,arr2))
#substract, multiply, divide, mod
# Out:
# [[19 31]
#  [54 66]
#  [85 98]]

# %%
print(numpy.power(arr1,arr2))
print(numpy.sqrt(arr1))
print(numpy.square(arr2))
# Out:
# [[      289     21952]
#  [  6250000 844596301]
#  [     6889  78074896]]
# [[4.12310563 5.29150262]
#  [7.07106781 7.81024968]
#  [9.11043358 9.69535971]]
# [[ 4  9]
#  [16 25]
#  [ 4 16]]
