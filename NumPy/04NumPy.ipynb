# %% [markdown]
# **Create NumPy array from CSV dataset**

# %%
import numpy

# %%
file=open("students50.csv","r")

# %%
lst=[]
for stud in file:
  try:
    lst.append(stud.split(','))
  except:
    pass

#print(lst)
arr=numpy.array(lst)
print(arr)
# Out:
# [['rollno' 'name' 'gender' 'age' 'mobile' 'email' 'course\n']
#  ['1' 'John Doe' 'M' '20' '1234567890' 'johndoe@example.com'
#   'Computer Science\n']
#  ['2' 'Jane Smith' 'F' '21' '2345678901' 'janesmith@example.com'
#   'Mechanical Engineering\n']
#  ['3' 'Robert Brown' 'M' '22' '3456789012' 'robertbrown@example.com'
#   'Civil Engineering\n']
#  ['4' 'Emily Davis' 'F' '20' '4567890123' 'emilydavis@example.com'
#   'Electrical Engineering\n']
#  ['5' 'Michael Wilson' 'M' '21' '5678901234' 'michaelwilson@example.com'
#   'Computer Science\n']
#  ['6' 'Sarah Johnson' 'F' '22' '6789012345' 'sarahjohnson@example.com'
#   'Business Administration\n']
#  ['7' 'David Lee' 'M' '20' '7890123456' 'davidlee@example.com'
#   'Chemical Engineering\n']
#  ['8' 'Amanda Martinez' 'F' '21' '8901234567'
#   'amandamartinez@example.com' 'Biotechnology\n']
#  ['9' 'James Anderson' 'M' '22' '9012345678' 'jamesanderson@example.com'
#   'Computer Science\n']
# ...

# %%
print(arr.shape)
# Out:
# (51, 7)
