# %% [markdown]
# **Retrive data from MySQL and store in numpy array**

# %%
pip install pymysql
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.1

# %%
import numpy
import pymysql

# %%
con=pymysql.connect(host='mysql-java-javaee-project.c.aivencloud.com',port=19179,user='avnadmin',password='AVNS_TEZ17S2CIEzgqRcBnb0',database='sharayudb')

# %%
curs=con.cursor()
curs.execute("select * from employees")
data=curs.fetchall()

# %%
arr=numpy.array(data)
print(arr)
# Out:
# [['100' 'Musaib umer' 'development' 'Java devloper' 'london' '50000.0']
#  ['102' 'Akshata' 'development' 'Employee' 'mumbai' '50000.0']
#  ['122' 'sejal' 'IT' 'Developer' 'mumbai' '56000.0']
#  ['123' 'praffull' 'marketing' 'executive' 'mumbai' '59700.0']
#  ['124' 'sharayu' 'development' 'data analyst' 'london' '71900.0']
#  ['125' 'shailaja' 'finance' 'manager' 'karachi' '70710.0']
#  ['126' 'megha' 'development' 'java developer' 'kolkata' '73000.0']
#  ['127' 'soham' 'data' 'cloud data engineer' 'liverpool' '85000.0']
#  ['128' 'jos buttler' 'finance' 'manager' 'london' '25970.0']
#  ['129' 'pat cummins' 'development' 'java developer' 'dubai' '56000.0']
#  ['130' 'mohammed salah' 'accounts' 'clerk' 'cairo' '71400.0']]

# %%
print(arr.shape)
# Out:
# (11, 6)

# %%
curs.execute("select * from accounts")
data=curs.fetchall()
arr=numpy.array(data)
print(arr)
# Out:
# [['992' 'sharayu' 'fixed' '226059.0']
#  ['993' 'praffull' 'current' '84054.0']
#  ['1001' 'charles leclerc' 'saving' '48672.0']
#  ['1002' 'maria sharapova' 'fixed' '25468.0']
#  ['1003' 'mitchell johnson' 'current' '26166.0']
#  ['1004' 'edan hazard' 'saving' '44670.0']
#  ['1005' 'robert lewandowski' 'saving' '23363.0']
#  ['1006' 'gabriel jesus' 'fixed' '40903.0']
#  ['1008' 'marcos alonso' 'saving' '36666.0']
#  ['1009' 'david luiz' 'current' '29547.0']
#  ['1010' 'steve smith' 'fixed' '67418.0']
#  ['1012' 'zaheer khan' 'saving' '24412.0']
#  ['1013' 'antoine griezman' 'fixed' '41498.0']
#  ['1014' 'nasser hussain' 'saving' '58146.0']
#  ['1015' 'fernando alonso' 'saving' '72868.0']
#  ['1018' 'cesar azpilicueta' 'current' '86057.0']
#  ['1020' 'ngolo kante' 'fixed' '61598.0']
#  ['1021' 'james anderson' 'current' '65783.0']
#  ['1022' 'ollie pope' 'saving' '82159.0']
#  ['1023' 'moin ali' 'current' '27624.0']
#  ['1024' 'sam curran' 'ppf' '72767.0']
#  ['1025' 'andreas christensen' 'saving' '74115.0']
#  ['1026' 'alvaro morata' 'saving' '104910.0']
#  ['1027' 'liam livingstone' 'current' '51674.0']
#  ['1028' 'mark wood' 'fixed' '83175.0']
#  ['1029' 'mohamed salah' 'saving' '91020.0']
#  ['1030' 'sadio mane' 'ppf' '52538.0']
#  ['1031' 'roberto firmino' 'fixed' '106194.0']
#  ['1032' 'alex oxlade chamberlain' 'current' '60810.0']
#  ['1033' 'alexandre lacazette' 'saving' '39183.0']
#  ['1034' 'raheem sterling' 'fixed' '69451.0']
#  ['1035' 'harry kane' 'current' '81933.0']
#  ['1036' 'carlos sainz' 'fixed' '109042.0']
#  ['1037' 'hugo lloris' 'saving' '87666.0']
#  ['1038' 'bill gates' 'current' '96881.0']
#  ['1039' 'amir khan' 'saving' '71985.0']
#  ['1040' 'adil rashid' 'ppf' '45647.0']
#  ['1041' 'chris jordan' 'saving' '59921.0']
#  ['1042' 'jason roy' 'saving' '32178.0']
#  ['1043' 'chris woakes' 'ppf' '57245.0']
#  ['1044' 'alex hales' 'saving' '41685.0']
#  ['1045' 'dawid malan' 'saving' '67167.0']
#  ['1046' 'ben stokes' 'saving' '62192.0']
#  ['1047' 'joe root' 'ppf' '140112.0']
#  ['1048' 'isa guha' 'saving' '78200.0']
#  ['1049' 'ravi shastri' 'saving' '64102.0']
#  ['1050' 'harsha bhogle' 'saving' '88089.0']
#  ['1051' 'lando norris' 'ppf' '85868.0']
#  ['1052' 'max verstappen' 'saving' '38747.0']
#  ['1053' 'varad somawar' 'fixed' '60638.0']
#  ['1054' 'harry brook' 'saving' '38500.0']
#  ['1055' 'glenn mcgrath' 'current' '41300.0']
#  ['1056' 'adam gilchrist' 'ppf' '35000.0']
#  ['7777' 'bharti airtel' 'current' '94155.0']]

# %%
print(arr.shape)
# Out:
# (54, 4)

# %%
con.close()
