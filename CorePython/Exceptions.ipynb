# %%
try:
  n=int(input('enter a number : '))
except:
  print('invalid number...reset to zero')
  n=0
sq=n*n
print(f"square of {n} is {sq}")
# Out:
# enter a number : sdlkfj
# invalid number...reset to zero
# square of 0 is 0

# %%
try:
  f=open("grace.apf")
  print(f.read())
except:
  print('cant read this file')
# Out:
# cant read this file
