# %%
player={
    'name':'mohammed salah',
    'personal':{
        'age':29,
        'gender':'male',
        'country':'egypt'
    },
    'professional':{
        'position':'midfielder',
        'club':'liverpool',
        'jersey':11
    },
    'health':{
        'height':175,
        'weight':88
    }
}

# %%
print(player)
# Out:
# {'name': 'mohammed salah', 'personal': {'age': 29, 'gender': 'male', 'country': 'egypt'}, 'professional': {'position': 'midfielder', 'club': 'liverpool', 'jersey': 11}, 'health': {'height': 175, 'weight': 88}}

# %%
print(player['personal']['gender'])
# Out:
# male
