# %% [markdown]
# # Working with Lists-1

# %%
lst=[]
print(type(lst))
# Out:
# <class 'list'>

# %%
lst.append("joe root")
lst.append("jos buttler")
lst.append("james anderson")
lst.append("ben stokes")

print(lst)
# Out:
# ['joe root', 'jos buttler', 'james anderson', 'ben stokes']

# %%
lst.append("ollie pope")
lst.append("mark wood")

print(lst)
# Out:
# ['joe root', 'jos buttler', 'james anderson', 'ben stokes', 'ollie pope', 'mark wood']

# %%
lst.insert(3,"pat cummins")
print(lst)
# Out:
# ['joe root', 'jos buttler', 'james anderson', 'pat cummins', 'ben stokes', 'ollie pope', 'mark wood']

# %%
lst.remove("james anderson")
print(lst)
# Out:
# ['joe root', 'jos buttler', 'pat cummins', 'ben stokes', 'ollie pope', 'mark wood']

# %%
print(len(lst))
# Out:
# 6

# %%
print(max(lst))
# Out:
# pat cummins

# %%
print(min(lst))
# Out:
# ben stokes

# %%
lst.reverse()
print(lst)
# Out:
# ['mark wood', 'ollie pope', 'ben stokes', 'pat cummins', 'jos buttler', 'joe root']

# %%
lst.sort()
print(lst)
# Out:
# ['ben stokes', 'joe root', 'jos buttler', 'mark wood', 'ollie pope', 'pat cummins']

# %%
lst.append('joe root')

# %%
print(lst)
# Out:
# ['ben stokes', 'joe root', 'jos buttler', 'mark wood', 'ollie pope', 'pat cummins', 'joe root']
