# %%
lst=['grace',2024,2.1,True]
print(lst)
# Out:
# ['grace', 2024, 2.1, True]

# %%
profile=['charles leclerc',16,'monaco','ferrari',['uk','usa','bahrain','china']]
print(profile)
# Out:
# ['charles leclerc', 16, 'monaco', 'ferrari', ['uk', 'usa', 'bahrain', 'china']]

# %%
print(profile[0])
# Out:
# charles leclerc

# %%
print(profile[4][2])
# Out:
# bahrain

# %%
app=['ajinkya','mba','aurangabad',['sql','mongodb','python']]
print(app)
# Out:
# ['ajinkya', 'mba', 'aurangabad', ['sql', 'mongodb', 'python']]

# %%
app[3].append('openai')
print(app)
# Out:
# ['ajinkya', 'mba', 'aurangabad', ['sql', 'mongodb', 'python', 'openai']]
