# %%
dic={
    "filmnm":['sholay','the matrix','pk'],
    "relyear":[1975,1999,2014],
    "director":["ramesh sippy","wachowsky brothers","rajkumar hirani"],
    "actor":["amitabh bachchan","keanu reeves","amir khan"],
    "genre":["action","action","comedy"],
    "imdbrating":[8.7,9.1,9.5]
}

# %%
print(dic)
# Out:
# {'filmnm': ['sholay', 'the matrix', 'pk'], 'relyear': [1975, 1999, 2014], 'director': ['ramesh sippy', 'wachowsky brothers', 'rajkumar hirani'], 'actor': ['amitabh bachchan', 'keanu reeves', 'amir khan'], 'genre': ['action', 'action', 'comedy'], 'imdbrating': [8.7, 9.1, 9.5]}

# %%
print(dic['actor'])
# Out:
# ['amitabh bachchan', 'keanu reeves', 'amir khan']

# %%
print(dic['actor'][1])
# Out:
# keanu reeves
