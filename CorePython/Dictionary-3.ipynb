# %%
dic={
    "accno":362563,
    "accnm":"Jos Buttler",
    "age":32,
    "gender":"male",
    "acctype":"Saving",
    "branch":"Andheri Mumbai",
    "opendate":"1 January 2020",
    "balance":89320.0
}
print(dic)
# Out:
# {'accno': 362563, 'accnm': 'Jos Buttler', 'age': 32, 'gender': 'male', 'acctype': 'Saving', 'branch': 'Andheri Mumbai', 'opendate': '1 January 2020', 'balance': 89320.0}

# %%
key=input("Enter key ")

if key in dic:
  print(dic[key])
else:
  print('information not found')
# Out:
# Enter key language
# information not found
