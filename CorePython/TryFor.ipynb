# %%
for i in range (1,11):
  print('welcome to python',i)
# Out:
# welcome to python 1
# welcome to python 2
# welcome to python 3
# welcome to python 4
# welcome to python 5
# welcome to python 6
# welcome to python 7
# welcome to python 8
# welcome to python 9
# welcome to python 10

# %%
for i in range(1,25,3):
  print(i)
# Out:
# 1
# 4
# 7
# 10
# 13
# 16
# 19
# 22

# %%
for i in range(25,0,-4):
  print(i)
# Out:
# 25
# 21
# 17
# 13
# 9
# 5
# 1

# %%
nm=['java','python','sql','spark','spring','hibernate','pandas']

for i in nm:
  print(i)
# Out:
# java
# python
# sql
# spark
# spring
# hibernate
# pandas

# %%
for i in range (1,6):
  for j in range (1,i+1):
    #print(str(j)+"  ",end="")
    print("*  ",end="")

  print()
# Out:
# *
# *  *
# *  *  *
# *  *  *  *
# *  *  *  *  *
