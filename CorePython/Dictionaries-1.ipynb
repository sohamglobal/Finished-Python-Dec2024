# %%
x={'praffull','grace'}
y={}
print(type(x))
print(type(y))
# Out:
# <class 'set'>
# <class 'dict'>

# %%
d={
    'custnm':'grace',
    'product':'laptop',
    'model':'latitude 5490',
    'company':'dell',
    'price':69500.00
}
print(type(d))
print(d)
# Out:
# <class 'dict'>
# {'custnm': 'grace', 'product': 'laptop', 'model': 'latitude 5490', 'company': 'dell', 'price': 69500.0}

# %%
d['processor']='intel i5'
print(d)
# Out:
# {'custnm': 'grace', 'product': 'laptop', 'model': 'latitude 5490', 'company': 'dell', 'price': 69500.0, 'processor': 'intel i5'}

# %%
d['price']=74500.0

# %%
print(d)
# Out:
# {'custnm': 'grace', 'product': 'laptop', 'model': 'latitude 5490', 'company': 'dell', 'price': 74500.0, 'processor': 'intel i5'}

# %%
print(d['custnm'])
# Out:
# grace

# %%
print(d['company'])
# Out:
# dell
