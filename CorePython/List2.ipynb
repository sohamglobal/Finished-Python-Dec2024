# %%
films=['speed','the matrix','sholay']
print(films)
# Out:
# ['speed', 'the matrix', 'sholay']

# %%
prod=['paramount','warner','20th century fox','bad robot']
films.extend(prod)
print(films)
# Out:
# ['speed', 'the matrix', 'sholay', 'paramount', 'warner', '20th century fox', 'bad robot']

# %%
print(films[3])
# Out:
# paramount

# %%
print(films[1:5])
# Out:
# ['the matrix', 'sholay', 'paramount', 'warner']

# %%
print(films[-2])
# Out:
# 20th century fox

# %%
print(films[3:])
# Out:
# ['paramount', 'warner', '20th century fox', 'bad robot']

# %%
print(films[:5])
# Out:
# ['speed', 'the matrix', 'sholay', 'paramount', 'warner']

# %%
print(films.pop())
print(films)
# Out:
# 20th century fox
# ['speed', 'the matrix', 'sholay', 'paramount', 'warner']

# %%
films.clear()
print(films)
# Out:
# []
