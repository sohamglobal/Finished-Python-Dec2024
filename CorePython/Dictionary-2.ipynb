# %%
emp={}

# %%
emp["empno"]=66
emp["empnm"]="joe root"
emp["company"]="microsoft"
emp["department"]="data"
emp["post"]="analyst"
emp["location"]="london"
emp["salary"]=75500.0

# %%
print(emp)
print(type(emp))
# Out:
# {'empno': 66, 'empnm': 'joe root', 'company': 'microsoft', 'department': 'data', 'post': 'analyst', 'location': 'london', 'salary': 75500.0}
# <class 'dict'>

# %%
print(len(emp))
# Out:
# 7

# %%
print(max(emp))
# Out:
# salary

# %%
print(min(emp))
# Out:
# company

# %%
print(emp[min(emp)])
# Out:
# microsoft

# %%
emp["location"]="sydney"
print(emp)
# Out:
# {'empno': 66, 'empnm': 'joe root', 'company': 'microsoft', 'department': 'data', 'post': 'analyst', 'location': 'sydney', 'salary': 75500.0}

# %%
emp["gender"]="male"
print(emp)
# Out:
# {'empno': 66, 'empnm': 'joe root', 'company': 'microsoft', 'department': 'data', 'post': 'analyst', 'location': 'sydney', 'salary': 75500.0, 'gender': 'male'}

# %%
print(emp.keys())
# Out:
# dict_keys(['empno', 'empnm', 'company', 'department', 'post', 'location', 'salary', 'gender'])

# %%
for key in emp.keys():
  print(key)
# Out:
# empno
# empnm
# company
# department
# post
# location
# salary
# gender

# %%
print(emp.values())
# Out:
# dict_values([66, 'joe root', 'microsoft', 'data', 'analyst', 'sydney', 75500.0, 'male'])

# %%
for val in emp.values():
  print(val)
# Out:
# 66
# joe root
# microsoft
# data
# analyst
# sydney
# 75500.0
# male

# %%
print(emp.items())
# Out:
# dict_items([('empno', 66), ('empnm', 'joe root'), ('company', 'microsoft'), ('department', 'data'), ('post', 'analyst'), ('location', 'sydney'), ('salary', 75500.0), ('gender', 'male')])

# %%
for it in emp.items():
  print(it)
# Out:
# ('empno', 66)
# ('empnm', 'joe root')
# ('company', 'microsoft')
# ('department', 'data')
# ('post', 'analyst')
# ('location', 'sydney')
# ('salary', 75500.0)
# ('gender', 'male')
