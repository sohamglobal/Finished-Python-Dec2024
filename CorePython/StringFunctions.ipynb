# %% [markdown]
# # String data type and String functions

# %%
nm="sohamglobal"
txt='you will never walk alone'
slogan="technology is power technology is future"
cho=""

# %%
print(nm)
print("liverpool says -"+txt)
# Out:
# sohamglobal
# liverpool says -you will never walk alone

# %%
print(type(slogan))
# Out:
# <class 'str'>

# %%
print("total characters present",len(txt))
# Out:
# total characters present 25

# %%
print(max(slogan))
# Out:
# y

# %%
print(min(slogan))

# %%
print(txt.count('e'))
print(slogan.count('is'))
# Out:
# 3
# 2

# %%
print(txt.upper())
print(txt.lower())
print(txt.capitalize())
print(txt.title())
# Out:
# YOU WILL NEVER WALK ALONE
# you will never walk alone
# You will never walk alone
# You Will Never Walk Alone

# %%
print(txt.isupper())
print(txt.islower())
# Out:
# False
# True

# %%
print(nm.isnumeric())
print(txt.isalpha())
# Out:
# False
# False

# %%
mob="07391966656"
print(mob.isnumeric())
ps="mission786"
print(ps.isalnum())
# Out:
# True
# True

# %%
print(slogan.startswith("What"))
print(slogan.startswith("tech"))
# Out:
# False
# True

# %%
print(slogan.endswith("?"))
print(slogan.endswith("future"))
# Out:
# False
# True

# %%
print(txt.split())
# Out:
# ['you', 'will', 'never', 'walk', 'alone']

# %%
film="pk,2014,rajkumar hirani,amir khan,comedy,india,hindi,8.7"
print(film.split(','))
print(film.split(',')[4])
# Out:
# ['pk', '2014', 'rajkumar hirani', 'amir khan', 'comedy', 'india', 'hindi', '8.7']
# comedy

# %%
nm="ethan hunt"
print(nm.center(25,'.'))
# Out:
# ........ethan hunt.......

# %%
mess="Hi {} welcome to python"
print(mess.format("JP"))
# Out:
# Hi JP welcome to python

# %%
mess="Thanks {name} for joining from {city}"
print(mess.format_map({'name':'ethan','city':'rome'}))
print(mess.format_map({'name':'grace','city':'london'}))
# Out:
# Thanks ethan for joining from rome
# Thanks grace for joining from london

# %%
s='.'
print(s.join(['ethan','grace','rome','praffull']))
# Out:
# ethan.grace.rome.praffull

# %%
s="welcome"
print(s.ljust(15,'.'))
print(s.rjust(15,'.'))
# Out:
# welcome........
# ........welcome

# %%
txt="      mission impossible     "
print(txt.strip())
print(txt.lstrip())
print(txt.rstrip())
# Out:
# mission impossible
# mission impossible
#       mission impossible

# %%
#table=str.maketrans("abcde","12345")
table=str.maketrans("abcde","!@#$%")
s="lets make things better"
print(s.translate(table))
# Out:
# l%ts m!k% things @%tt%r

# %%
txt="you will never walk alone"
print(txt.replace("walk","travel"))
# Out:
# you will never travel alone

# %%
print(txt[9])
print(txt[9:13])
print(txt[-5])
# Out:
# n
# neve
# a

# %%
nm="ethan hunt"
print(nm[::-1])
txt="believe the unbelievable"
print(txt[::-1])
# Out:
# tnuh nahte
# elbaveilebnu eht eveileb

# %%
s="silent"
s1="listed"
print(sorted(s))
print(sorted(s1))
# Out:
# ['e', 'i', 'l', 'n', 's', 't']
# ['d', 'e', 'i', 'l', 's', 't']

# %%
print(sorted(s)==sorted(s1))
# Out:
# False

# %%
s="Desperate Times Desperate Measures"
print(s.swapcase())
# Out:
# dESPERATE tIMES dESPERATE mEASURES
