# %%
n=1
while n!=0:
  n=int(input('enter a number '))
  sq=n*n
  if n!=0:
    print('square is %d' %sq)
  else:
    print('good by mr.anderson')
# Out:
# enter a number 45
# square is 2025
# enter a number 22
# square is 484
# enter a number 67
# square is 4489
# enter a number -98
# square is 9604
# enter a number 0
# good by mr.anderson

# %%
cho="yes"

while cho=="yes" or cho=='Yes':
  amt=float(input('enter purchase amount '))
  disc=amt*13/100
  print('discount will be %.2f' %disc)

  cho=input('do you have any more customers? ')
# Out:
# enter purchase amount 1000
# discount will be 130.00
# do you have any more customers? yes
# enter purchase amount 3400
# discount will be 442.00
# do you have any more customers? Yes
# enter purchase amount 2100
# discount will be 273.00
# do you have any more customers? yES
