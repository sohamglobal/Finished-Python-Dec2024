# %% [markdown]
# # Tuples in python

# %%
nm=('jos buttler','pat cummins','steve smith','adam gilchrist','joe root','jos buttler')
print(type(nm))
# Out:
# <class 'tuple'>

# %%
print(nm)
# Out:
# ('jos buttler', 'pat cummins', 'steve smith', 'adam gilchrist', 'joe root', 'jos buttler')

# %%
print(nm[3])
print(nm[2:5])
# Out:
# adam gilchrist
# ('steve smith', 'adam gilchrist', 'joe root')

# %%
print(len(nm))
# Out:
# 6

# %%
print(max(nm))
# Out:
# steve smith

# %%
print(min(nm))
# Out:
# adam gilchrist

# %%
#nm.append("wasim akram")
#nm.remove("steve smith")
#nm.insert(2,"praffull")

# %%
print(nm.count('jos buttler'))
# Out:
# 2

# %%
tup=('charles leclerc','ferrari',16,34.67,True)
print(tup)
# Out:
# ('charles leclerc', 'ferrari', 16, 34.67, True)

# %%
for item in tup:
  print(type(item))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
tup=('charles leclerc','ferrari',16,34.67,True,('max verstappen','lando norris','george russel'))
print(tup)
# Out:
# ('charles leclerc', 'ferrari', 16, 34.67, True, ('max verstappen', 'lando norris', 'george russel'))

# %%
print(tup[5][0])
# Out:
# max verstappen

# %%
tup=('praffull','co-founder','sohamglobal',['java','python','c#','sql'])
print(tup)
# Out:
# ('praffull', 'co-founder', 'sohamglobal', ['java', 'python', 'c#', 'sql'])

# %%
print(tup[3])
# Out:
# ['java', 'python', 'c#', 'sql']

# %%
tup[3].append("spark")
print(tup)
# Out:
# ('praffull', 'co-founder', 'sohamglobal', ['java', 'python', 'c#', 'sql', 'spark'])
