# %%
pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 23.6 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 17.8 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.10.1

# %%
from pymongo import MongoClient

# %%
client=MongoClient("mongodb+srv://praffull:mongodb913@ethancluster.nz1sx.mongodb.net/?retryWrites=true&w=majority&appName=EthanCluster")

# %%
db=client["spiderdb"]
coll=db["customers"]

# %%
nm=input('Enter customer name : ')
gn=input('Enter gender : ')
ag=int(input('Enter age : '))
ct=input('Enter city : ')

dic={}
dic['name']=nm
dic['gender']=gn
dic['age']=ag
dic['city']=ct
print(dic)

coll.insert_one(dic)
print('New customer added successfully')
# Out:
# Enter customer name : Jos Buttler
# Enter gender : Male
# Enter age : 32
# Enter city : Manchester
# {'name': 'Jos Buttler', 'gender': 'Male', 'age': 32, 'city': 'Manchester'}
# New customer added successfully

# %%
coll=db["workers"]

# %%
wid=int(input('Enter worker id : '))
nm=input('Enter name : ')
dp=input('Enter department : ')
po=input('Enter post : ')
sl=float(input('Enter salary : '))

dic={}
dic['workerid']=wid
dic['name']=nm
dic['departmenmt']=dp
dic['post']=po
dic['salary']=sl
print(dic)

coll.insert_one(dic)
print('worker added successfully')
# Out:
# Enter worker id : 3687
# Enter name : ricky ponting
# Enter department : admin
# Enter post : manager
# Enter salary : 75000
# {'workerid': 3687, 'name': 'ricky ponting', 'departmenmt': 'admin', 'post': 'manager', 'salary': 75000.0}
# worker added successfully
