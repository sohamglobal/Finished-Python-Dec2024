# %%
pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 18.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 19.3 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient

# %%
client=MongoClient("mongodb+srv://praffull:mongodb913@ethancluster.nz1sx.mongodb.net/?retryWrites=true&w=majority&appName=EthanCluster")

# %%
db=client["spiderdb"]
coll=db["workers"]

# %%
nm=input('Enter name : ')
lo=input('Enter new location : ')

condition={}
condition['name']=nm

change={}
change['location']=lo

upd={'$set':change}

print(condition)
print(change)
print(upd)

result=coll.update_one(condition,upd)
print(result.matched_count)
if result.matched_count>0:
  print('worker document updated')
else:
  print('Not updated..name not found')
# Out:
# Enter name : praffull
# Enter new location : london
# {'name': 'praffull'}
# {'location': 'london'}
# {'$set': {'location': 'london'}}
# 0
# Not updated..name not found

# %%
db=client["netflixdb"]
coll=db["celebrities"]

# %%
nm=input('Enter name : ')
ct=input('Enter city : ')

condition={'name':nm}
change={'city':ct}
upd={'$set':change}

result=coll.update_one(condition,upd)

print(f'{result.matched_count} celebrity city updated')
# Out:
# Enter name : praffull
# Enter city : london
# 0 celebrity city updated
