# %% [markdown]
# **Cloud MongoDB data retrieval**

# %%
pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 19.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 19.8 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient

# %%
try:
  client=MongoClient("mongodb+srv://praffull:mongodb913@ethancluster.nz1sx.mongodb.net/?retryWrites=true&w=majority&appName=EthanCluster")
  print('python connected to mongodb cloud successfully')
except:
  print('mongodb connectivity failed')
# Out:
# python connected to mongodb cloud successfully

# %%
db=client["spiderdb"]
coll=db["workers"]

# %%
for doc in coll.find():
  print(doc)
# Out:
# {'_id': ObjectId('67335b4ff3eca764098e71aa'), 'workerid': 3684, 'name': 'tom cruise', 'department': 'sales', 'post': 'manager', 'location': 'new york', 'salary': 47200}
# {'_id': ObjectId('67335cb0f3eca764098e71ac'), 'workerid': 3686, 'name': 'adam gilchrist', 'department': 'marketing', 'states': ['punjab', 'kashmir', 'bengal'], 'salary': 87210}

# %%
coll=db["students"]

# %%
for doc in coll.find():
  print(doc)
# Out:
# {'_id': ObjectId('67335894f3eca764098e71a8'), 'rollno': 151, 'studnnm': 'jos buttler', 'qualification': 'btech', 'branch': 'electronics', 'city': 'manchester', 'course': 'core java', 'startdt': '1 november 2024'}
# {'_id': ObjectId('6733595cf3eca764098e71a9'), 'rollno': 152, 'studnm': 'pat cummins', 'occupation': 'manager', 'experience': 9, 'course': 'generative ai', 'startdt': '15 october 2024', 'fees': 25000, 'mobile': '7391966656'}
# {'_id': ObjectId('6734a6cbe17439a8e8c43756'), 'rollno': 155, 'studnm': 'steve smith', 'course': 'core java'}

# %%
coll=db["customers"]

# %%
for doc in coll.find():
  print(doc['name'])
# Out:
# Alice Johnson
# Benjamin White
# Charlotte Brown
# Daniel Smith
# Emily Davis
# Freddie Wilson
# Grace Taylor
# Harry Moore
# Isla Anderson
# Jack Thomas
# Katie Jackson
# Leo Harris
# Mia Martin
# Nathan Lee
# Olivia Clark
# Paul Lewis
# Quinn Walker
# Ryan Hall
# Sophia Young
# Thomas King

# %%
for doc in coll.find({'gender':'Female'}):
  print(doc)
# Out:
# {'_id': ObjectId('6734a8c9e17439a8e8c43757'), 'name': 'Alice Johnson', 'gender': 'Female', 'age': 28, 'city': 'London'}
# {'_id': ObjectId('6734a8c9e17439a8e8c43759'), 'name': 'Charlotte Brown', 'gender': 'Female', 'age': 22, 'city': 'Birmingham'}
# {'_id': ObjectId('6734a8c9e17439a8e8c4375b'), 'name': 'Emily Davis', 'gender': 'Female', 'age': 31, 'city': 'Glasgow'}
# {'_id': ObjectId('6734a8c9e17439a8e8c4375d'), 'name': 'Grace Taylor', 'gender': 'Female', 'age': 26, 'city': 'Bristol'}
# {'_id': ObjectId('6734a8c9e17439a8e8c4375f'), 'name': 'Isla Anderson', 'gender': 'Female', 'age': 37, 'city': 'Sheffield'}
# {'_id': ObjectId('6734a8c9e17439a8e8c43761'), 'name': 'Katie Jackson', 'gender': 'Female', 'age': 30, 'city': 'Leicester'}
# {'_id': ObjectId('6734a8c9e17439a8e8c43763'), 'name': 'Mia Martin', 'gender': 'Female', 'age': 24, 'city': 'Bradford'}
# {'_id': ObjectId('6734a8c9e17439a8e8c43765'), 'name': 'Olivia Clark', 'gender': 'Female', 'age': 29, 'city': 'Newcastle'}
# ...

# %%
db=client["netflixdb"]
coll=db['films']

# %%
for doc in coll.find():
  print(doc)
# Out:
# {'_id': '151', 'filmnm': 'sholay', 'genre': 'action', 'releaseyr': 1975, 'written': 'salim javed', 'director': 'ramesh sippy', 'actor': 'amitabh bachchan', 'actress': 'jaya bhaduri', 'music': 'r d burman', 'villain': 'amjad khan', 'budgetmn': 30, 'collectionmn': 410}
# {'_id': '152', 'filmnm': 'pk', 'genre': 'comedy', 'releaseyr': 2014, 'director': 'rajkumar hirani', 'actor': 'amir khan', 'actress': 'anushka sharma', 'budgetmn': 850, 'collectionmn': 8540}
# {'_id': '153', 'filmnm': 'the matrix', 'genre': 'action', 'releaseyr': 1999, 'director': 'wachowski bros', 'actor': 'keanu reeves', 'actress': 'carrie-anne moss', 'budgetmn': 4725, 'collectionmn': 34950}
# {'_id': '154', 'filmnm': 'mughal e azam', 'genre': 'romance', 'releaseyr': 1960, 'director': 'k asif', 'actor': 'dilip kumar', 'actress': 'madhubala', 'music': 'naushad', 'budgetmn': 15, 'collectionmn': 110}
# ...

# %%
nm=input('Enter film name to search : ')
dic={'filmnm':nm}
#print(dic)
for doc in coll.find(dic):
  print(doc)
# Out:
# Enter film name to search : the matrix
# {'_id': '153', 'filmnm': 'the matrix', 'genre': 'action', 'releaseyr': 1999, 'director': 'wachowski bros', 'actor': 'keanu reeves', 'actress': 'carrie-anne moss', 'budgetmn': 4725, 'collectionmn': 34950}

# %%
gn=input('Enter genre : ')
dic={'genre':gn}
for doc in coll.find(dic):
  print(doc['filmnm'])
# Out:
# Enter genre : action
# sholay
# the matrix
# mi5 rogue nation
